# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharathyramakrishnan/Applied-Generative-AI-Specialization/blob/main/Langchain_and_HuggingFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries required
! pip install langchain-huggingface
# For API calls
! pip install huggingface_hub
! pip install transformers
! pip install accelerate
! pip install bitsandbytes
! pip install langchain
#! pip install transformers==4.21.0 torch==1.11.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.7/408.7 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.13
#     Uninstalling langchain-core-0.3.13:
#       Successfully uninstalled langchain-core-0.3.13
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 6.3 MB/s eta 0:00:00
# ...

# %%
# Environment Secret Key
from google.colab import userdata
sec_key=userdata.get("HF_TOKEN")
print(sec_key)
# Out:
# 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

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
sec_key=userdata.get("GenAI-Read")
print(sec_key)
# Out:
# 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

# %%
import os
os.environ["GenAI-Read"]=sec_key

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
llm
# Out:
# HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.3', temperature=0.7, stop_sequences=[], server_kwargs={}, model_kwargs={'max_length': 128, 'token': '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'}, model='mistralai/Mistral-7B-Instruct-v0.3', client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>, async_client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>)

# %%
llm.invoke("What is Generative AI")
# Out:
# ' is and how it works\n\nGenerative AI is a type of artificial intelligence (AI) that uses algorithms to create new content, such as images, text, music, or even 3D models. It is called "generative" because it can generate new, unique content that was not explicitly programmed by humans.\n\nGenerative AI models are trained on large datasets of examples, such as a dataset of images of cats or a dataset of text written by humans. The model learns patterns and features from the data and uses these patterns to generate new content.\n\nThere are several types of generative AI models, but the most popular ones are:\n\n1. Generative adversarial networks (GANs): GANs consist of two neural networks: a generator network that creates new content and a discriminator network that tries to distinguish the generated content from real content. The generator network learns to generate more realistic content by trying to fool the discriminator network.\n2. Variational autoencoders (VAEs): VAEs are a t
# ...

# %%
from langchain import PromptTemplate, LLMChain

question="Who won the Cricket World cup in the year 2011"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# {'question': 'Who won the Cricket World cup in the year 2011', 'text': '\n\nThe Cricket World Cup is held every four years. So, if we subtract 4 from the year 2022, we get the year 2018. But we are asked for the year 2011.\n\nSo, to find the year 2011, we subtract 4 from 2015 (the previous year). This gives us 2011.\n\nNow, to find the winner of the Cricket World Cup in 2011, we need to look back at the history of the tournament. The 2011 Cricket World Cup was won by India.\n\nSo, the answer is India.'}
# <ipython-input-10-70285da664b5>:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain=LLMChain(llm=llm,prompt=prompt)

# %% [markdown]
# HuggingFace Pipeline - To download entire model into the local environment we can use pipeline

# %%
# Load model directly
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM
# from transformers import  pipeline

# %%
model_id = "gpt2"
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
import torch
from transformers import pipeline

# %%
pipe=pipeline("text-generation",model=model, tokenizer=tokenizer,max_new_tokens=100)

hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf.invoke("What is machine learning")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'What is machine learning? It consists of making your brain smarter and more complex.\n\nAdvertisement\n\nThis article first appeared in Wired.com. The author will receive a copy from IT Magazine. To access previous stories on Machine Learning and other topics, visit this blog post.'

# %%
# use HuggingFacePipelines with GPU
gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    device = -1, #replace with device_map="auto" to use the accelerate library.
    pipeline_kwargs={"max_new_tokens": 100},
)

# %%
from langchain import PromptTemplate, LLMChain

question="What is Artificial Engine"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)
#print(prompt)

# %%
chain=prompt|gpu_llm

# %%
question="What is artificial intelligence?"
result = chain.invoke({"question": question})
print(result)
# Out:
# Question: What is artificial intelligence?
# Answer: Let's think step by step.
# What is the difference between something called artificial intelligence and machine intelligence? The difference is not clear, as there is probably plenty more data that can be gleaned.
# What is a machine?
# A machine is a program that executes a task. The task itself consists of what we call tasks. A task may be a particular task, perhaps a list of tasks. A task may be called a job. A task may run in a particular way, from one point to another. All of this
